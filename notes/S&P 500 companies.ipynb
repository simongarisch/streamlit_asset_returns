# %% [markdown]
# ## S&P 500 companies

# %%
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

# %%
import pandas as pd

result = pd.read_html(url)

# %%
type(result)
# Out:
# list

# %%
len(result)
# Out:
# 2

# %%
result
# Out:
# [    Symbol                Security SEC filings             GICS Sector  \
#  0      MMM              3M Company     reports             Industrials
#  1      ABT     Abbott Laboratories     reports             Health Care
#  2     ABBV             AbbVie Inc.     reports             Health Care
#  3     ABMD             ABIOMED Inc     reports             Health Care
#  4      ACN           Accenture plc     reports  Information Technology
#  ..     ...                     ...         ...                     ...
#  500    YUM         Yum! Brands Inc     reports  Consumer Discretionary
#  501   ZBRA      Zebra Technologies     reports  Information Technology
#  502    ZBH  Zimmer Biomet Holdings     reports             Health Care
#  503   ZION           Zions Bancorp     reports              Financials
#  504    ZTS                  Zoetis     reports             Health Care
#
#                        GICS Sub Industry     Headquarters Location  \
# ...

# %%
result[0]
# Out:
#     Symbol                Security SEC filings             GICS Sector  \
# 0      MMM              3M Company     reports             Industrials
# 1      ABT     Abbott Laboratories     reports             Health Care
# 2     ABBV             AbbVie Inc.     reports             Health Care
# 3     ABMD             ABIOMED Inc     reports             Health Care
# 4      ACN           Accenture plc     reports  Information Technology
# ..     ...                     ...         ...                     ...
# 500    YUM         Yum! Brands Inc     reports  Consumer Discretionary
# 501   ZBRA      Zebra Technologies     reports  Information Technology
# 502    ZBH  Zimmer Biomet Holdings     reports             Health Care
# 503   ZION           Zions Bancorp     reports              Financials
# 504    ZTS                  Zoetis     reports             Health Care
#
#                       GICS Sub Industry     Headquarters Location  \
# ...

# %%
result[1]
# Out:
#                  Date  Added                               Removed  \
#                  Date Ticker                      Security  Ticker
# 0        May 22, 2020    WST  West Pharmaceutical Services      HP
# 1        May 12, 2020    DPZ                Domino's Pizza    CPRI
# 2        May 12, 2020   DXCM                        Dexcom     AGN
# 3       April 6, 2020    NaN                           NaN       M
# 4       April 6, 2020    NaN                           NaN     RTN
# ..                ...    ...                           ...     ...
# 235  December 5, 2000   INTU                        Intuit      BS
# 236  December 5, 2000    SBL           Symbol Technologies      OI
# 237  December 5, 2000    AYE              Allegheny Energy     GRA
# 238  December 5, 2000    ABK               Ambac Financial     CCK
# 239     July 27, 2000   JDSU                  JDS Uniphase     RAD
#
#                                                                    Reason
# ...

# %%
df = result[0].fillna(0).set_index("Symbol")

# %%
df
# Out:
#                       Security SEC filings             GICS Sector  \
# Symbol
# MMM                 3M Company     reports             Industrials
# ABT        Abbott Laboratories     reports             Health Care
# ABBV               AbbVie Inc.     reports             Health Care
# ABMD               ABIOMED Inc     reports             Health Care
# ACN              Accenture plc     reports  Information Technology
# ...                        ...         ...                     ...
# YUM            Yum! Brands Inc     reports  Consumer Discretionary
# ZBRA        Zebra Technologies     reports  Information Technology
# ZBH     Zimmer Biomet Holdings     reports             Health Care
# ZION             Zions Bancorp     reports              Financials
# ZTS                     Zoetis     reports             Health Care
#
#                          GICS Sub Industry     Headquarters Location  \
# Symbol
# MMM               Industrial Conglomerates       St. Paul, Minnesota
# ...

# %%
import pandas as pd


URL = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"


def collect_sp500_companies() -> pd.DataFrame:
    """ Returns a pandas dataframe containing all stocks in the S&P 500. """
    df_list = pd.read_html(url)
    return df_list[0].fillna(0).set_index("Symbol")

# %%
collect_sp500_companies()
# Out:
#                       Security SEC filings             GICS Sector  \
# Symbol
# MMM                 3M Company     reports             Industrials
# ABT        Abbott Laboratories     reports             Health Care
# ABBV               AbbVie Inc.     reports             Health Care
# ABMD               ABIOMED Inc     reports             Health Care
# ACN              Accenture plc     reports  Information Technology
# ...                        ...         ...                     ...
# YUM            Yum! Brands Inc     reports  Consumer Discretionary
# ZBRA        Zebra Technologies     reports  Information Technology
# ZBH     Zimmer Biomet Holdings     reports             Health Care
# ZION             Zions Bancorp     reports              Financials
# ZTS                     Zoetis     reports             Health Care
#
#                          GICS Sub Industry     Headquarters Location  \
# Symbol
# MMM               Industrial Conglomerates       St. Paul, Minnesota
# ...
